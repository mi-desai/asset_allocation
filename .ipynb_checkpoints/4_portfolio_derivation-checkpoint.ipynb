# %%
# !conda activate cvxpy
# !pip install cvxpy
# !pip install PyPortfolioOpt
# Out:
# C:\Projects\vrs_project>set "JAVA_HOME="
# Requirement already satisfied: cvxpy in c:\users\michael desai\anaconda\lib\site-packages (1.1.6)
# Requirement already satisfied: ecos>=2 in c:\users\michael desai\anaconda\lib\site-packages (from cvxpy) (2.0.7.post1)
# Requirement already satisfied: osqp>=0.4.1 in c:\users\michael desai\anaconda\lib\site-packages (from cvxpy) (0.6.1)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\michael desai\anaconda\lib\site-packages (from cvxpy) (1.3.1)
# Requirement already satisfied: numpy>=1.15 in c:\users\michael desai\anaconda\lib\site-packages (from cvxpy) (1.16.5)
# Requirement already satisfied: scs>=1.1.6 in c:\users\michael desai\anaconda\lib\site-packages (from cvxpy) (2.1.2)
# Requirement already satisfied: future in c:\users\michael desai\anaconda\lib\site-packages (from osqp>=0.4.1->cvxpy) (0.17.1)
# Requirement already satisfied: PyPortfolioOpt in c:\users\michael desai\anaconda\lib\site-packages (1.2.6)
# Requirement already satisfied: numpy<2.0,>=1.12 in c:\users\michael desai\anaconda\lib\site-packages (from PyPortfolioOpt) (1.16.5)
# Requirement already satisfied: cvxopt<2.0,>=1.2 in c:\users\michael desai\anaconda\lib\site-packages (from PyPortfolioOpt) (1.2.5.post1)
# Requirement already satisfied: pandas>=0.19 in c:\users\michael desai\anaconda\lib\site-packages (from PyPortfolioOpt) (0.25.1)
# Requirement already satisfied: scipy<2.0,>=1.3 in c:\users\michael desai\anaconda\lib\site-packages (from PyPortfolioOpt) (1.3.1)
# Requirement already satisfied: cvxpy<2.0,>=1.0 in c:\users\michael desai\anaconda\lib\site-packages (from PyPortfolioOpt) (1.1.6)
# Requirement already satisfied: pytz>=2017.2 in c:\users\michael desai\anaconda\lib\site-packages (from pandas>=0.19->PyPortfolioOpt) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\michael desai\anaconda\lib\site-packages (from pandas>=0.19->PyPortfolioOpt) (2.8.0)
# Requirement already satisfied: ecos>=2 in c:\users\michael desai\anaconda\lib\site-packages (from cvxpy<2.0,>=1.0->PyPortfolioOpt) (2.0.7.post1)
# Requirement already satisfied: scs>=1.1.6 in c:\users\michael desai\anaconda\lib\site-packages (from cvxpy<2.0,>=1.0->PyPortfolioOpt) (2.1.2)
# Requirement already satisfied: osqp>=0.4.1 in c:\users\michael desai\anaconda\lib\site-packages (from cvxpy<2.0,>=1.0->PyPortfolioOpt) (0.6.1)
# Requirement already satisfied: six>=1.5 in c:\users\michael desai\anaconda\lib\site-packages (from python-dateutil>=2.6.1->pandas>=0.19->PyPortfolioOpt) (1.12.0)
# Requirement already satisfied: future in c:\users\michael desai\anaconda\lib\site-packages (from osqp>=0.4.1->cvxpy<2.0,>=1.0->PyPortfolioOpt) (0.17.1)

# %%
import utilities as ut
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pypfopt
from pypfopt import risk_models, expected_returns, plotting
pypfopt.__version__
# Out:
# '1.2.6'

# %%
def combine_portfolio(data):
    import pandas as pd
    result = pd.DataFrame([])
    for series in data:
        series.index.rename('Date', inplace=True)
        series = series.pct_change()
        if result.empty == True:
            result = series
        else:
            result = pd.merge(result, series, how='inner', on='Date')     
    return result   

raw_data = ut.clean_data()
portfolio = combine_portfolio(raw_data)

# %%
# Shows that past in-sample covariance of returns calculations are pretty good estimators of future covariance
# Given this, using covariance matrices to create the weights for the optimal portfolio is a better strategy than using expected return methods

past_return_covariance = risk_models.sample_cov(portfolio.loc['2005': '2018'].resample('W').mean().dropna(), returns_data=True, frequency=252)
future_return_covariance = risk_models.sample_cov(portfolio.loc['2019': '2020'].resample('W').mean().dropna(), returns_data=True, frequency=252)

plotting.plot_covariance(past_return_covariance, plot_correlation=True)
plotting.plot_covariance(future_return_covariance, plot_correlation=True)
plt.show()

# %%
sample_cov = risk_models.sample_cov(portfolio, returns_data=True, frequency=252)
plotting.plot_covariance(sample_cov, plot_correlation=True)
plt.show()

# %%
S = risk_models.risk_matrix(portfolio, returns_data=True, method='exp_cov')
plotting.plot_covariance(S, plot_correlation=True)
plt.show()

# %%
V = risk_models.CovarianceShrinkage(portfolio, returns_data=True, frequency=252).ledoit_wolf(shrinkage_target='constant_correlation')

plotting.plot_covariance(V, plot_correlation=True)

plt.show()

# %%
from pypfopt import expected_returns

#mu = expected_returns.capm_return(portfolio, returns_data=True, risk_free_rate=0.025, compounding=False, frequency=252)
mu = expected_returns.ema_historical_return(portfolio, returns_data=True, frequency=252)

print(mu)

mu.plot.barh(figsize=(8, 5))
# Out:
# asset1     0.072789
# asset2     0.087107
# asset3     0.089704
# asset4     0.001691
# asset5     0.080612
# asset6     0.282086
# asset7     0.169779
# asset8     0.089704
# asset9     0.030843
# asset10   -0.444381
# mkt        0.025698
# Name: 2020-07-23 00:00:00, dtype: float64

# %%
from pypfopt import EfficientFrontier

ef = EfficientFrontier(mu, V, weight_bounds=(0, 1))
ef.max_sharpe()
cleaned_weights = ef.clean_weights()
pd.Series(cleaned_weights).plot.barh()
print(raw_weights)
ef.save_weights_to_file('weights/max_sharpe_weights.csv')
ef.portfolio_performance(verbose=True)
# Out:
# OrderedDict([('asset1', 0.0), ('asset2', 0.0524977927607795), ('asset3', 0.1745103566867581), ('asset4', 0.0113652498278362), ('asset5', 0.5485654899205983), ('asset6', 0.0288175653382859), ('asset7', 0.0097331887789501), ('asset8', 0.1745103566867917), ('asset9', 0.0), ('asset10', 0.0), ('mkt', 0.0)])
# Expected annual return: 10.6%
# Annual volatility: 3.3%
# Sharpe Ratio: 2.62
# (0.10630943709075355, 0.032992887441401254, 2.6160013198010614)

# %%
alternate_ef = EfficientFrontier(mu, V, weight_bounds=(0, 1))
alternate_ef.min_volatility()
cleaned_weights = alternate_ef.clean_weights()
pd.Series(cleaned_weights).plot.barh()
print(raw_weights)
alternate_ef.save_weights_to_file('weights/min_vol_weights.csv')
alternate_ef.portfolio_performance(verbose=True)
# Out:
# OrderedDict([('asset1', 0.0), ('asset2', 0.0524977927607795), ('asset3', 0.1745103566867581), ('asset4', 0.0113652498278362), ('asset5', 0.5485654899205983), ('asset6', 0.0288175653382859), ('asset7', 0.0097331887789501), ('asset8', 0.1745103566867917), ('asset9', 0.0), ('asset10', 0.0), ('mkt', 0.0)])
# Expected annual return: 8.5%
# Annual volatility: 2.9%
# Sharpe Ratio: 2.21
# (0.08458210553902995, 0.02918725980782114, 2.2126813535857948)

# %%
from pypfopt import CLA, plotting

cla = CLA(mu, V)
cla.min_volatility()
cla.portfolio_performance(verbose=True)
# Out:
# Expected annual return: 5.0%
# Annual volatility: 2.9%
# Sharpe Ratio: 1.02
# (0.049898872743236004, 0.02918725980782114, 1.024380943606915)

# %%
ax = plotting.plot_efficient_frontier(cla, showfig=False)
